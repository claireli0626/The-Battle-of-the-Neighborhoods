# %% [markdown]
# ## 2. A description of the data and how it will be used to solve the problem.

# %% [markdown]
# #### 2.1 Data Description

# %% [markdown]
# Data to consider when choosing a pizza restaurant location involves:
# * Demographics information extracted from [Census API tool](https://api.census.gov/data.html);
# * Business vendor information extracted from [Foursquare API Too](https://developer.foursquare.com/docs/api-reference/venues/search/);
# * and Johnson County zip code data from [Mongabay Zip Data](https://data.mongabay.com/igapo/zip_codes/metropolitan-areas/metro-zip/Kansas%20City%20(MO-KS)1.html).
#
# The census database I used in this project is 2017 Economic Annual Surveys. The basis of reporting ZIP Code Business Patterns is tabulated at the establishment level. An establishment is a single physical location at which business is conducted. Number of employees and annual payroll for each zip code area are extracted to add to this project model. Thus, the household wealthiness and the number target customers are added to the prediction modal as parameters. Johnson Count Business vendor data including vendor location, vendor cross street, distance to entrance, business categories is added to my analysis. I found the location by zip code level from Mongabay by use of Beautiful Soup to scrape the web.

# %% [markdown]
# #### 2.2 Data Wrangling

# %% [markdown]
# ##### 2.21 Import Data and handle missing values

# %% [markdown]
# Import all the libraries and packages

# %%
# !conda install bs4 --yes
from bs4 import BeautifulSoup
from urllib.request import urlopen
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

# !conda install -c conda-forge folium=0.5.0 --yes
import folium
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - bs4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.9.0       |           py36_0         167 KB
#     bs4-4.9.0                  |                0           9 KB
#     ca-certificates-2020.1.1   |                0         125 KB
#     certifi-2020.4.5.1         |           py36_0         155 KB
#     openssl-1.1.1g             |       h7b6447c_0         2.5 MB
#     soupsieve-2.0              |             py_0          33 KB
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   beautifulsoup4     pkgs/main/linux-64::beautifulsoup4-4.9.0-py36_0
#   bs4                pkgs/main/noarch::bs4-4.9.0-0
#   soupsieve          pkgs/main/noarch::soupsieve-2.0-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2020.4.5~ --> pkgs/main::ca-certificates-2020.1.1-0
#   certifi            conda-forge::certifi-2020.4.5.1-py36h~ --> pkgs/main::certifi-2020.4.5.1-py36_0
#   openssl            conda-forge::openssl-1.1.1g-h516909a_0 --> pkgs/main::openssl-1.1.1g-h7b6447c_0
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2020 | 125 KB    | ##################################### | 100%
# beautifulsoup4-4.9.0 | 167 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.5 MB    | ##################################### | 100%
# soupsieve-2.0        | 33 KB     | ##################################### | 100%
# certifi-2020.4.5.1   | 155 KB    | ##################################### | 100%
# bs4-4.9.0            | 9 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.9.2         |   py36h45558ae_0         613 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.0.3               |   py36h830a2c2_1        11.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.9.2-py36h45558ae_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.9-py_1
#   importlib-metadata conda-forge/linux-64::importlib-metadata-1.6.0-py36h9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.3-py36h830a2c2_1
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   requests           conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.9-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#   zipp               conda-forge/noarch::zipp-3.1.0-py_0
#
# The following packages will be UPDATED:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2020.4.5.1-hecc5488_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi              pkgs/main::certifi-2020.4.5.1-py36_0 --> conda-forge::certifi-2020.4.5.1-py36h9f0ad1d_0
#   openssl              pkgs/main::openssl-1.1.1g-h7b6447c_0 --> conda-forge::openssl-1.1.1g-h516909a_0
#
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# cryptography-2.9.2   | 613 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# pandas-1.0.3         | 11.1 MB   | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.22.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# First to create latitude & longitude coordinates for centroids of Johnson county, KS neighborhoods. BeautifulSoup is used to capture zip codes of cities in Johnson County, from [Mongabay Zip Data](https://data.mongabay.com/igapo/zip_codes/metropolitan-areas/metro-zip/Kansas%20City%20(MO-KS)1.html).

# %%
 
f = requests.get('https://data.mongabay.com/igapo/zip_codes/metropolitan-areas/metro-zip/Kansas%20City%20(MO-KS)1.html') 

kc_data = BeautifulSoup(f.text)
match = kc_data.find('table', class_='boldtable')

# %%
rows = match.find_all ('tr')
 
dt_kc=[]
for r in range(len(rows)):
    
    dt_kctext = rows[r].find_all('td')
    temp=[]
    for val in dt_kctext:
        temp.append(val.text)
    dt_kc.append(temp)

    


column = ['postal','phone','county','state','city','district']

df = pd.DataFrame(dt_kc, columns=column)

df['Postal Code'] = df['postal'].str[:5]
 
df['postal'] = df['postal'].str[5:]

df_kc = df.rename(columns={'postal':'city_name'})
 
df_kc = df_kc[['city_name','Postal Code','county','state']]
df_johnson = df_kc.loc[df['county'] =='Johnson County']
 
print(df_johnson)
# Out:
#             city_name Postal Code          county        state
# 276           De Soto       66018  Johnson County  Kansas - KS
# 277    Clearview City       66019  Johnson County  Kansas - KS
# 278           De Soto       66019  Johnson County  Kansas - KS
# 280          Edgerton       66021  Johnson County  Kansas - KS
# 284           Gardner       66030  Johnson County  Kansas - KS
# ..                ...         ...             ...          ...
# 482   Shawnee Mission       66285  Johnson County  Kansas - KS
# 483                Sm       66285  Johnson County  Kansas - KS
# 484            Lenexa       66286  Johnson County  Kansas - KS
# 485           Shawnee       66286  Johnson County  Kansas - KS
# 486   Shawnee Mission       66286  Johnson County  Kansas - KS
#
# [177 rows x 4 columns]

# %% [markdown]
# Add the latitude & longitude keys to each city centers with pgeocode.Nominatim package.

# %%
# !pip install pgeocode
# Out:
# Collecting pgeocode
#   Downloading https://files.pythonhosted.org/packages/86/44/519e3db3db84acdeb29e24f2e65991960f13464279b61bde5e9e96909c9d/pgeocode-0.2.1-py2.py3-none-any.whl
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pgeocode) (2.23.0)
# Requirement already satisfied: pandas in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pgeocode) (1.0.3)
# Requirement already satisfied: numpy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pgeocode) (1.18.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->pgeocode) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->pgeocode) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->pgeocode) (2.9)
# Requirement already satisfied: pytz>=2017.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas->pgeocode) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas->pgeocode) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas->pgeocode) (1.14.0)
# Installing collected packages: pgeocode
# Successfully installed pgeocode-0.2.1

# %%
import pgeocode

nomi = pgeocode.Nominatim('us')

df_loc=[]
for i in df_johnson['Postal Code']:
    df_loc.append(nomi.query_postal_code(i))
    
column=['postal_code','country code','place_name','state_name', 'county_name','county_code','community_name','community_code','latitude','longitude','accuracy']
df_j = pd.DataFrame(df_loc, columns = column)
df_p=df_j.reset_index(drop=True) 
df_po=df_p[['postal_code','latitude','longitude']]
df_po=df_po.rename(columns={'postal_code':'Postal Code'})

# %%
df_jo = pd.merge(df_johnson,df_po, how='right', on='Postal Code')
#df_jo = df_johnson.append(df_po, sort=False)
df_jo
# Out:
#             city_name Postal Code          county        state  latitude  \
# 0             De Soto       66018  Johnson County  Kansas - KS   38.9462
# 1      Clearview City       66019  Johnson County  Kansas - KS       NaN
# 2             De Soto       66019  Johnson County  Kansas - KS       NaN
# 3      Clearview City       66019  Johnson County  Kansas - KS       NaN
# 4             De Soto       66019  Johnson County  Kansas - KS       NaN
# ..                ...         ...             ...          ...       ...
# 866           Shawnee       66286  Johnson County  Kansas - KS   39.0417
# 867   Shawnee Mission       66286  Johnson County  Kansas - KS   39.0417
# 868            Lenexa       66286  Johnson County  Kansas - KS   39.0417
# 869           Shawnee       66286  Johnson County  Kansas - KS   39.0417
# 870   Shawnee Mission       66286  Johnson County  Kansas - KS   39.0417
#
#      longitude
# 0     -94.9714
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 866   -94.7202
# 867   -94.7202
# 868   -94.7202
# 869   -94.7202
# 870   -94.7202
#
# [871 rows x 6 columns]

# %% [markdown]
# Clean data, drop NA and duplicate data. Concatenate city areas with same postal code so I am able to use zip code to search for business venues with a radius of 1500 meters.

# %%
df_jo=df_jo.drop_duplicates().dropna().reset_index(drop=True)
df_jon = pd.DataFrame(columns = list(df_jo.columns))
zips = set(df_jo['Postal Code'])
for zipp in zips:
    rows = df_jo[df_jo['Postal Code'] == zipp].reset_index(drop=True)
    city_names = rows['city_name'].tolist()
    city_name = '/'.join(city_names)
    new_row = {}
    new_row['city_name'] = city_name
    for col in list(rows.columns):
        if col is not 'city_name':
            new_row[col] = rows.loc[0][col]
    df_jon.loc[len(df_jon)] = new_row
df_jon
# Out:
#                                             city_name Postal Code  \
# 0                        Shawnee/ Shawnee Mission/ Sm       66218
# 1    Overland/ Overland Park/ Shawnee Mission/ Sm/...       66223
# 2        Overland/ Overland Park/ Shawnee Mission/ Sm       66282
# 3                       Lenexa/ Olathe/ Overland Park       66062
# 4    Lenexa/ Overland/ Overland Park/ Shawnee Miss...       66215
# 5                Lenexa/ Shawnee/ Shawnee Mission/ Sm       66227
# 6    Lenexa/ Op/ Overland Park/ Shawnee Mission/ S...       66251
# 7    Merriam/ Overland/ Overland Park/ Prairie Vil...       66204
# 8                                            Edgerton       66021
# 9                                         Spring Hill       66083
# 10        Mission/ Overland Park/ Shawnee Mission/ Sm       66201
# 11           Overland/ Overland Park/ Shawnee Mission       66212
# 12                                             Olathe       66051
# 13                       Shawnee/ Shawnee Mission/ Sm       66226
# 14               Lenexa/ Shawnee/ Shawnee Mission/ Sm       66220
# 15                 J C Penney Co/ Shawnee Mission/ Sm       66276
# 16   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66224
# 17   Lenexa/ Overland/ Overland Park/ Shawnee Miss...       66213
# 18       Overland/ Overland Park/ Shawnee Mission/ Sm       66225
# 19   Lenexa/ Overland/ Overland Park/ Shawnee/ Sha...       66214
# 20   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66209
# 21   Countryside/ Merriam/ Mission/ Overland/ Over...       66202
# 22   Mission Hills/ Overland/ Overland Park/ Prair...       66208
# 23                 J C Penney Co/ Shawnee Mission/ Sm       66250
# 24                        Lenexa/ Shawnee Mission/ Sm       66285
# 25               Lenexa/ Shawnee/ Shawnee Mission/ Sm       66219
# 26                            Overland Park/ Stilwell       66085
# 27                                             Olathe       66061
# 28                                            De Soto       66018
# 29   Lenexa/ Overland/ Overland Park/ Shawnee Miss...       66210
# 30                                             Olathe       66063
# 31                                            Gardner       66030
# 32   Fairway/ Mission/ Mission Woods/ Roeland Park...       66205
# 33   Leawood/ Overland/ Overland Park/ Prairie Vil...       66206
# 34                       Mission/ Shawnee Mission/ Sm       66222
# 35        Overland Park/ Shawnee Mission/ Sm/ Stanley       66283
# 36                                        New Century       66031
# 37                   Lenexa/ Shawnee/ Shawnee Mission       66286
# 38   Leawood/ Overland/ Overland Park/ Prairie Vil...       66207
# 39               Lenexa/ Shawnee/ Shawnee Mission/ Sm       66216
# 40   Overland/ Overland Park/ Shawnee Mission/ Sm/...       66221
# 41   Merriam/ Op/ Overland/ Overland Park/ Shawnee...       66203
# 42   Lake Quivira/ Lenexa/ Quivira/ Shawnee/ Shawn...       66217
# 43   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66211
#
#             county        state  latitude  longitude
# 0   Johnson County  Kansas - KS   39.0417   -94.7202
# 1   Johnson County  Kansas - KS   38.8619   -94.6610
# 2   Johnson County  Kansas - KS   38.8999   -94.8320
# 3   Johnson County  Kansas - KS   38.8733   -94.7752
# 4   Johnson County  Kansas - KS   38.9536   -94.7336
# 5   Johnson County  Kansas - KS   38.9536   -94.7336
# 6   Johnson County  Kansas - KS   38.8999   -94.8320
# 7   Johnson County  Kansas - KS   38.9928   -94.6771
# 8   Johnson County  Kansas - KS   38.7811   -95.0094
# 9   Johnson County  Kansas - KS   38.7631   -94.8246
# 10  Johnson County  Kansas - KS   39.0278   -94.6558
# 11  Johnson County  Kansas - KS   38.9568   -94.6832
# 12  Johnson County  Kansas - KS   38.8999   -94.8320
# 13  Johnson County  Kansas - KS   39.0417   -94.7202
# 14  Johnson County  Kansas - KS   38.9536   -94.7336
# 15  Johnson County  Kansas - KS   38.8999   -94.8320
# 16  Johnson County  Kansas - KS   38.8591   -94.6314
# 17  Johnson County  Kansas - KS   38.8982   -94.7049
# 18  Johnson County  Kansas - KS   38.8999   -94.8320
# 19  Johnson County  Kansas - KS   38.9649   -94.7209
# 20  Johnson County  Kansas - KS   38.9667   -94.6169
# 21  Johnson County  Kansas - KS   39.0278   -94.6558
# 22  Johnson County  Kansas - KS   38.9917   -94.6336
# 23  Johnson County  Kansas - KS   38.9536   -94.7336
# 24  Johnson County  Kansas - KS   38.9536   -94.7336
# 25  Johnson County  Kansas - KS   38.9536   -94.7336
# 26  Johnson County  Kansas - KS   38.7902   -94.6643
# 27  Johnson County  Kansas - KS   38.8865   -94.8204
# 28  Johnson County  Kansas - KS   38.9462   -94.9714
# 29  Johnson County  Kansas - KS   38.9273   -94.7143
# 30  Johnson County  Kansas - KS   38.8999   -94.8320
# 31  Johnson County  Kansas - KS   38.8075   -94.9157
# 32  Johnson County  Kansas - KS   39.0278   -94.6558
# 33  Johnson County  Kansas - KS   38.9667   -94.6169
# 34  Johnson County  Kansas - KS   39.0278   -94.6558
# 35  Johnson County  Kansas - KS   38.8999   -94.8320
# 36  Johnson County  Kansas - KS   38.8249   -94.8992
# 37  Johnson County  Kansas - KS   39.0417   -94.7202
# 38  Johnson County  Kansas - KS   38.9575   -94.6452
# 39  Johnson County  Kansas - KS   39.0417   -94.7202
# 40  Johnson County  Kansas - KS   38.8636   -94.7103
# 41  Johnson County  Kansas - KS   39.0417   -94.7202
# 42  Johnson County  Kansas - KS   39.0417   -94.7202
# 43  Johnson County  Kansas - KS   38.9667   -94.6169

# %% [markdown]
# #### Foursquare

# %% [markdown]
# Use Foursquare API to get venue informations in each city neighborhood. First to take a look at the data patten for each venue in Olathe neighborhood. So I am able to do further analysis to extract useful information to add to models as key parameter.

# %%
address = 'Olathe, KS'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of olathe are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of olathe are 38.8838856, -94.81887.

# %%
CLIENT_ID = 'FU3FNGEIK2IW5VS01MZC1ZVR2W20LSCEZOUCIDBB2WOU051W' # your Foursquare ID
CLIENT_SECRET = '3DCGCPEJ4YIEDGTY5QMLI3MPS3CLWLA2SOZRIOU2OUGOPCMS' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

LIMIT = 100
radius = 1000
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ebc40f202a172001b31a55d'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Central Core',
#   'headerFullLocation': 'Central Core, Olathe',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 14,
#   'suggestedBounds': {'ne': {'lat': 38.89288560900001,
#     'lng': -94.80732969008133},
#    'sw': {'lat': 38.87488559099999, 'lng': -94.83041030991868}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd1ecbc046076b029d17271',
#        'name': 'Kansas Coffee Café',
#        'location': {'address': '101 E Park St',
#         'crossStreet': 'at N Cherry St.',
#         'lat': 38.881981099879475,
#         'lng': -94.81945893487695,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.881981099879475,
#           'lng': -94.81945893487695},
#          {'label': 'entrance', 'lat': 38.88194, 'lng': -94.819196}],
#         'distance': 218,
#         'postalCode': '66061',
#         'cc': 'US',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['101 E Park St (at N Cherry St.)',
#          'Olathe, KS 66061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd1ecbc046076b029d17271-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e495a56b61c6886484d0fcc',
#        'name': 'Downtown Diner',
#        'location': {'address': '409 E Santa Fe St',
#         'lat': 38.883297835970644,
#         'lng': -94.8157864823268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.883297835970644,
#           'lng': -94.8157864823268}],
#         'distance': 275,
#         'postalCode': '66061',
#         'cc': 'US',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['409 E Santa Fe St',
#          'Olathe, KS 66061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e495a56b61c6886484d0fcc-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '509a927de4b0c6891066de41',
#        'name': 'Tropicana',
#        'location': {'address': '539 E Santa Fe St',
#         'lat': 38.88349757109715,
#         'lng': -94.80974414688772,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.88349757109715,
#           'lng': -94.80974414688772}],
#         'distance': 791,
#         'postalCode': '66061',
#         'cc': 'US',
#         'neighborhood': 'Central Core',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['539 E Santa Fe St',
#          'Olathe, KS 66061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1507777',
#         'url': 'https://www.grubhub.com/restaurant/paleterias-tropicana-539-east-santa-fe-street-olathe/1507777?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1507777',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-509a927de4b0c6891066de41-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f0a42dde4b0c3ff85d3cd29',
#        'name': "Dub's V's Bar & Deli",
#        'location': {'address': '122 N Cherry St',
#         'lat': 38.88274461864791,
#         'lng': -94.81929628626497,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.88274461864791,
#           'lng': -94.81929628626497},
#          {'label': 'entrance', 'lat': 38.882734, 'lng': -94.819316}],
#         'distance': 132,
#         'postalCode': '66061',
#         'cc': 'US',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['122 N Cherry St',
#          'Olathe, KS 66061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '38490016'}},
#       'referralId': 'e-0-4f0a42dde4b0c3ff85d3cd29-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af63149f964a5201d0222e3',
#        'name': "Mom's Kitchen",
#        'location': {'address': '530 E Santa Fe St',
#         'lat': 38.88393419430012,
#         'lng': -94.81024648417612,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.88393419430012,
#           'lng': -94.81024648417612}],
#         'distance': 747,
#         'postalCode': '66061',
#         'cc': 'US',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['530 E Santa Fe St',
#          'Olathe, KS 66061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af63149f964a5201d0222e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b479990f964a520ee3626e3',
#        'name': "Smokin' Joe's BBQ",
#        'location': {'address': '519 E Santa Fe St',
#         'crossStreet': 'btwn N State & Cooper St',
#         'lat': 38.883285733537036,
#         'lng': -94.81018176435491,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.883285733537036,
#           'lng': -94.81018176435491}],
#         'distance': 755,
#         'postalCode': '66061',
#         'cc': 'US',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['519 E Santa Fe St (btwn N State & Cooper St)',
#          'Olathe, KS 66061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1058411',
#         'url': 'https://www.grubhub.com/restaurant/smokin-joes-bbq-519-e-santa-fe-st-olathe/1058411?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1058411',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b479990f964a520ee3626e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc47126d4c0ad9c0f6ed26d',
#        'name': 'Food Truck Friday',
#        'location': {'address': '1729 Grand Blvd',
#         'crossStreet': '18th Street',
#         'lat': 38.88199767914521,
#         'lng': -94.8198284707694,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.88199767914521,
#           'lng': -94.8198284707694}],
#         'distance': 225,
#         'postalCode': '64108',
#         'cc': 'US',
#         'city': 'Kansas City',
#         'state': 'MO',
#         'country': 'United States',
#         'formattedAddress': ['1729 Grand Blvd (18th Street)',
#          'Kansas City, MO 64108',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc47126d4c0ad9c0f6ed26d-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2f2b58213c2d7f6d5a305d',
#        'name': "Olathe Farmer's Market",
#        'location': {'address': '200 W Santa Fe St',
#         'crossStreet': 'Poplar',
#         'lat': 38.88469132249151,
#         'lng': -94.82103805543018,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.88469132249151,
#           'lng': -94.82103805543018}],
#         'distance': 208,
#         'postalCode': '66061',
#         'cc': 'US',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['200 W Santa Fe St (Poplar)',
#          'Olathe, KS 66061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa941735',
#          'name': 'Farmers Market',
#          'pluralName': 'Farmers Markets',
#          'shortName': "Farmer's Market",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_farmersmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2f2b58213c2d7f6d5a305d-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50f6efcee4b0f74491d8c7d5',
#        'name': "Monk's Roast Beef",
#        'location': {'lat': 38.88288997902334,
#         'lng': -94.82102793327294,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.88288997902334,
#           'lng': -94.82102793327294}],
#         'distance': 217,
#         'postalCode': '64108',
#         'cc': 'US',
#         'city': 'Kansas City',
#         'state': 'MO',
#         'country': 'United States',
#         'formattedAddress': ['Kansas City, MO 64108', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50f6efcee4b0f74491d8c7d5-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc59a172271f27051319e1a',
#        'name': 'Mill Creek Center',
#        'location': {'lat': 38.881691689423974,
#         'lng': -94.81598920912863,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.881691689423974,
#           'lng': -94.81598920912863}],
#         'distance': 349,
#         'cc': 'US',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['Olathe, KS', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc59a172271f27051319e1a-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57f13f27cd10af69f167c59f',
#        'name': 'Kauffman Machine Shop',
#        'location': {'address': '408 S Kansas Ave',
#         'lat': 38.877522,
#         'lng': -94.820694,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.877522,
#           'lng': -94.820694}],
#         'distance': 725,
#         'postalCode': '66061',
#         'cc': 'US',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['408 S Kansas Ave',
#          'Olathe, KS 66061',
#          'United States']},
#        'categories': [{'id': '5454144b498ec1f095bff2f2',
#          'name': 'Construction & Landscaping',
#          'pluralName': 'Construction & Landscaping',
#          'shortName': 'Construction',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57f13f27cd10af69f167c59f-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0ae7c36071a593bc76e032',
#        'name': 'Olathe Civic Theatre Association - OCTA',
#        'location': {'address': '500 E Loula St',
#         'lat': 38.88078139095214,
#         'lng': -94.81114510476083,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.88078139095214,
#           'lng': -94.81114510476083}],
#         'distance': 753,
#         'postalCode': '66061',
#         'cc': 'US',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['500 E Loula St',
#          'Olathe, KS 66061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '119971593'}},
#       'referralId': 'e-0-4c0ae7c36071a593bc76e032-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd848a7da85224b83c34bca',
#        'name': 'Bolillo Fresh Mex Subs',
#        'location': {'address': '539 E Santa Fe St',
#         'crossStreet': 'Cooper',
#         'lat': 38.8835566,
#         'lng': -94.809731,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.8835566,
#           'lng': -94.809731}],
#         'distance': 792,
#         'postalCode': '66061',
#         'cc': 'US',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['539 E Santa Fe St (Cooper)',
#          'Olathe, KS 66061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd848a7da85224b83c34bca-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b3d432cf964a520329125e3',
#        'name': 'Walgreens',
#        'location': {'address': '545 E Santa Fe St',
#         'lat': 38.8832237,
#         'lng': -94.8085649,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 38.8832237,
#           'lng': -94.8085649},
#          {'label': 'entrance', 'lat': 38.883279, 'lng': -94.808666}],
#         'distance': 896,
#         'postalCode': '66061',
#         'cc': 'US',
#         'city': 'Olathe',
#         'state': 'KS',
#         'country': 'United States',
#         'formattedAddress': ['545 E Santa Fe St',
#          'Olathe, KS 66061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b3d432cf964a520329125e3-13'}]}]}}

# %% [markdown]
# As I can tell from the above database, the following factors will be considered when choosing the business location:
# * Access: One fo the most important factors is how accessible your potential location is. Distance to entrance and crossroad information need to be added to the API  request.
# * Business type: business type is what I need predict for.  This item will be added to my test/train model.
# * Popularity of the business: All the venues in Johnson County area have not been rated based on the data pulled from Foursquare.  I will skip this part.
# * Tax: The restaurant business income rates and sales tax rates imposed on customer are not changed too much within Johnson County. Combined tax rate for Johnson County is 9.48%.

# %%
CLIENT_ID = 'FU3FNGEIK2IW5VS01MZC1ZVR2W20LSCEZOUCIDBB2WOU051W' # your Foursquare ID
CLIENT_SECRET = '3DCGCPEJ4YIEDGTY5QMLI3MPS3CLWLA2SOZRIOU2OUGOPCMS' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
def getNearbyVenues(names,postal, latitudes, longitudes):
    
    venues_list=[]
    LIMIT = 100
    radius = 1500
    for cname,pos,lat,lng in zip(names,postal,latitudes,longitudes):
 
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        for v in results:
            try:
                venues_list.append([(
                cname,
                pos,
                lat, 
                lng, 
                v['venue']['name'], 
                v['venue']['location']['lat'], 
                v['venue']['location']['lng'],
                v['venue']['location']['distance'],
                v['venue']['categories'][0]['name'],
                v['venue']['location']['crossStreet'])])
        
           
            except:
                venues_list.append([(
                cname,
                pos,
                lat, 
                lng, 
                v['venue']['name'], 
                v['venue']['location']['lat'], 
                v['venue']['location']['lng'],
                v['venue']['location']['distance'],
                v['venue']['categories'][0]['name'],
                'NA')])
         

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])

    nearby_venues.columns = ['City',
                  'Postal Code',
                  'Latitude', 
                  'Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Dis to entrance',
                  'Venue Category',
                  'Venue crosssSreet',]
    
    return(nearby_venues)

# %%
jo_venues = getNearbyVenues(names=df_jon['city_name'],
                            postal=df_jon['Postal Code'],
                            longitudes=df_jon['longitude'],
                            latitudes=df_jon['latitude']
                            )

jo_venues
# Out:
#                                                    City Postal Code  Latitude  \
# 0                          Shawnee/ Shawnee Mission/ Sm       66218   39.0417
# 1                          Shawnee/ Shawnee Mission/ Sm       66218   39.0417
# 2                          Shawnee/ Shawnee Mission/ Sm       66218   39.0417
# 3                          Shawnee/ Shawnee Mission/ Sm       66218   39.0417
# 4                          Shawnee/ Shawnee Mission/ Sm       66218   39.0417
# ...                                                 ...         ...       ...
# 1760   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66211   38.9667
# 1761   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66211   38.9667
# 1762   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66211   38.9667
# 1763   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66211   38.9667
# 1764   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66211   38.9667
#
#       Longitude                                  Venue  Venue Latitude  \
# 0      -94.7202                     West Flanders Park       39.030392
# 1      -94.7202     West Flanders Park & Walking Trail       39.029862
# 2      -94.7202                        Black Swan Lake       39.041802
# 3      -94.7202          Bierman's Christmas Tree Farm       39.049750
# 4      -94.7202          KC's Neighborhood Bar & Grill       39.043677
# ...         ...                                    ...             ...
# 1760   -94.6169  State Line Rd & Bannister Rd/ 95th St       38.956705
# 1761   -94.6169                           Ceramic Café       38.957999
# 1762   -94.6169                     Hallmark Creations       38.958188
# 1763   -94.6169                   Oz's MAQ Donut House       38.956166
# 1764   -94.6169                               Hallmark       38.957614
#
#       Venue Longitude  Venue Dis to entrance       Venue Category  \
# 0          -94.713196                   1396                 Park
# 1          -94.713282                   1447                 Park
# 2          -94.730938                    928                 Lake
# 3          -94.723537                    941        Garden Center
# 4          -94.704676                   1360                  Bar
# ...               ...                    ...                  ...
# 1760       -94.608141                   1346         Intersection
# 1761       -94.629457                   1455  Arts & Crafts Store
# 1762       -94.629920                   1472            Gift Shop
# 1763       -94.627651                   1497           Donut Shop
# 1764       -94.629727                   1501            Gift Shop
#
#      Venue crosssSreet
# 0     Near Johnson Dr.
# 1               nieman
# 2                   NA
# 3                   NA
# 4                   NA
# ...                ...
# 1760                NA
# 1761                NA
# 1762                NA
# 1763                NA
# 1764      Mission Road
#
# [1765 rows x 10 columns]

# %%
jo_pc=jo_venues.groupby('Postal Code').count()

# %% [markdown]
# Now, I will use census API tool to collect demographics data for the Johnson County neighborhood. The census database I used in this project is 2017 Economic Annual Surveys. Employee numbers and annual payroll ($1,000) are two variables which will be considered.  So restaurants owner are able to make judgment on neighborhood size and neighborhood wealthness of perspective customers.

# %%
def getpopinfo(zip_codes):
    jo_emp=[]
    zip_list=[]
    for zip_code in zip_codes:
        url = 'https://api.census.gov/data/2017/zbp?get=NAICS2017_LABEL,EMP,GEO_ID,PAYANN,EMPSZES_LABEL&for=zip%20code:{}&NAICS2017=00&key=234d6c235a105e7e50723b5e4e747b03c4692a24'.format(
        zip_code)
        
        res = requests.get(url)
        
        try:
            zip_list.append(res.json()[1])           
        except:
            pass
        
    column= res.json()[0]
    jo_emp = pd.DataFrame(zip_list,columns=column)
 

    return(jo_emp)

# %%
df_jovenue=df_jon['Postal Code'].values.tolist()

# %%
df_jovenues = getpopinfo(zip_codes=df_jovenue)
df_jovenues
# Out:
#           NAICS2017_LABEL    EMP          GEO_ID   PAYANN       EMPSZES_LABEL  \
# 0   Total for all sectors   1280  8610000US66218    64208  All establishments
# 1   Total for all sectors  10456  8610000US66223   332174  All establishments
# 2   Total for all sectors     18  8610000US66282      223  All establishments
# 3   Total for all sectors  29366  8610000US66062  1224442  All establishments
# 4   Total for all sectors  29052  8610000US66215  1436549  All establishments
# 5   Total for all sectors   4693  8610000US66227   203755  All establishments
# 6   Total for all sectors      0  8610000US66251        0  All establishments
# 7   Total for all sectors  10259  8610000US66204   452242  All establishments
# 8   Total for all sectors   1562  8610000US66021    66227  All establishments
# 9   Total for all sectors   1833  8610000US66083    74597  All establishments
# 10  Total for all sectors    944  8610000US66201   111642  All establishments
# 11  Total for all sectors  14498  8610000US66212   571321  All establishments
# 12  Total for all sectors    256  8610000US66051    11691  All establishments
# 13  Total for all sectors   3024  8610000US66226    95609  All establishments
# 14  Total for all sectors   1911  8610000US66220    52976  All establishments
# 15  Total for all sectors   1848  8610000US66224   106895  All establishments
# 16  Total for all sectors  16159  8610000US66213   950712  All establishments
# 17  Total for all sectors    254  8610000US66225    15554  All establishments
# 18  Total for all sectors  18171  8610000US66214   921095  All establishments
# 19  Total for all sectors   7459  8610000US66209   308546  All establishments
# 20  Total for all sectors  12732  8610000US66202   816177  All establishments
# 21  Total for all sectors   6170  8610000US66208   253635  All establishments
# 22  Total for all sectors      0  8610000US66250        0  All establishments
# 23  Total for all sectors    356  8610000US66285     7125  All establishments
# 24  Total for all sectors  23359  8610000US66219  1521906  All establishments
# 25  Total for all sectors   2448  8610000US66085   144608  All establishments
# 26  Total for all sectors  26024  8610000US66061  1314633  All establishments
# 27  Total for all sectors   1999  8610000US66018   137717  All establishments
# 28  Total for all sectors  27524  8610000US66210  1970824  All establishments
# 29  Total for all sectors     64  8610000US66063     1951  All establishments
# 30  Total for all sectors   4214  8610000US66030   137553  All establishments
# 31  Total for all sectors   4784  8610000US66205   234060  All establishments
# 32  Total for all sectors   3465  8610000US66206   165927  All establishments
# 33  Total for all sectors    112  8610000US66222     3275  All establishments
# 34  Total for all sectors    108  8610000US66283     5512  All establishments
# 35  Total for all sectors   4425  8610000US66031   255409  All establishments
# 36  Total for all sectors      6  8610000US66286      124  All establishments
# 37  Total for all sectors   4726  8610000US66207   190805  All establishments
# 38  Total for all sectors   4592  8610000US66216   201305  All establishments
# 39  Total for all sectors   3108  8610000US66221   101311  All establishments
# 40  Total for all sectors   8610  8610000US66203   346628  All establishments
# 41  Total for all sectors   3103  8610000US66217   103879  All establishments
# 42  Total for all sectors  30534  8610000US66211  2447778  All establishments
#
#    NAICS2017 zip code
# 0         00    66218
# 1         00    66223
# 2         00    66282
# 3         00    66062
# 4         00    66215
# 5         00    66227
# 6         00    66251
# 7         00    66204
# 8         00    66021
# 9         00    66083
# 10        00    66201
# 11        00    66212
# 12        00    66051
# 13        00    66226
# 14        00    66220
# 15        00    66224
# 16        00    66213
# 17        00    66225
# 18        00    66214
# 19        00    66209
# 20        00    66202
# 21        00    66208
# 22        00    66250
# 23        00    66285
# 24        00    66219
# 25        00    66085
# 26        00    66061
# 27        00    66018
# 28        00    66210
# 29        00    66063
# 30        00    66030
# 31        00    66205
# 32        00    66206
# 33        00    66222
# 34        00    66283
# 35        00    66031
# 36        00    66286
# 37        00    66207
# 38        00    66216
# 39        00    66221
# 40        00    66203
# 41        00    66217
# 42        00    66211

# %%
df_joks = df_jovenues.drop(['NAICS2017_LABEL','GEO_ID','EMPSZES_LABEL','NAICS2017'], axis=1).rename(columns={'EMP':'Employee No.','PAYANN':'Ann payroll','zip code':'Postal Code'})

df_joks
# Out:
#    Employee No. Ann payroll Postal Code
# 0          1280       64208       66218
# 1         10456      332174       66223
# 2            18         223       66282
# 3         29366     1224442       66062
# 4         29052     1436549       66215
# 5          4693      203755       66227
# 6             0           0       66251
# 7         10259      452242       66204
# 8          1562       66227       66021
# 9          1833       74597       66083
# 10          944      111642       66201
# 11        14498      571321       66212
# 12          256       11691       66051
# 13         3024       95609       66226
# 14         1911       52976       66220
# 15         1848      106895       66224
# 16        16159      950712       66213
# 17          254       15554       66225
# 18        18171      921095       66214
# 19         7459      308546       66209
# 20        12732      816177       66202
# 21         6170      253635       66208
# 22            0           0       66250
# 23          356        7125       66285
# 24        23359     1521906       66219
# 25         2448      144608       66085
# 26        26024     1314633       66061
# 27         1999      137717       66018
# 28        27524     1970824       66210
# 29           64        1951       66063
# 30         4214      137553       66030
# 31         4784      234060       66205
# 32         3465      165927       66206
# 33          112        3275       66222
# 34          108        5512       66283
# 35         4425      255409       66031
# 36            6         124       66286
# 37         4726      190805       66207
# 38         4592      201305       66216
# 39         3108      101311       66221
# 40         8610      346628       66203
# 41         3103      103879       66217
# 42        30534     2447778       66211

# %% [markdown]
# Combine all the variables in one dataset.

# %%
df_kcjo = pd.merge(jo_venues,df_joks, how='left', on='Postal Code')
df_kcjo
# Out:
#                                                    City Postal Code  Latitude  \
# 0                          Shawnee/ Shawnee Mission/ Sm       66218   39.0417
# 1                          Shawnee/ Shawnee Mission/ Sm       66218   39.0417
# 2                          Shawnee/ Shawnee Mission/ Sm       66218   39.0417
# 3                          Shawnee/ Shawnee Mission/ Sm       66218   39.0417
# 4                          Shawnee/ Shawnee Mission/ Sm       66218   39.0417
# ...                                                 ...         ...       ...
# 1760   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66211   38.9667
# 1761   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66211   38.9667
# 1762   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66211   38.9667
# 1763   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66211   38.9667
# 1764   Leawood/ Overland/ Overland Park/ Shawnee Mis...       66211   38.9667
#
#       Longitude                                  Venue  Venue Latitude  \
# 0      -94.7202                     West Flanders Park       39.030392
# 1      -94.7202     West Flanders Park & Walking Trail       39.029862
# 2      -94.7202                        Black Swan Lake       39.041802
# 3      -94.7202          Bierman's Christmas Tree Farm       39.049750
# 4      -94.7202          KC's Neighborhood Bar & Grill       39.043677
# ...         ...                                    ...             ...
# 1760   -94.6169  State Line Rd & Bannister Rd/ 95th St       38.956705
# 1761   -94.6169                           Ceramic Café       38.957999
# 1762   -94.6169                     Hallmark Creations       38.958188
# 1763   -94.6169                   Oz's MAQ Donut House       38.956166
# 1764   -94.6169                               Hallmark       38.957614
#
#       Venue Longitude  Venue Dis to entrance       Venue Category  \
# 0          -94.713196                   1396                 Park
# 1          -94.713282                   1447                 Park
# 2          -94.730938                    928                 Lake
# 3          -94.723537                    941        Garden Center
# 4          -94.704676                   1360                  Bar
# ...               ...                    ...                  ...
# 1760       -94.608141                   1346         Intersection
# 1761       -94.629457                   1455  Arts & Crafts Store
# 1762       -94.629920                   1472            Gift Shop
# 1763       -94.627651                   1497           Donut Shop
# 1764       -94.629727                   1501            Gift Shop
#
#      Venue crosssSreet Employee No. Ann payroll
# 0     Near Johnson Dr.         1280       64208
# 1               nieman         1280       64208
# 2                   NA         1280       64208
# 3                   NA         1280       64208
# 4                   NA         1280       64208
# ...                ...          ...         ...
# 1760                NA        30534     2447778
# 1761                NA        30534     2447778
# 1762                NA        30534     2447778
# 1763                NA        30534     2447778
# 1764      Mission Road        30534     2447778
#
# [1765 rows x 12 columns]

# %% [markdown]
# ##### 2.22 Data Data Standarization and Data Normalization

# %% [markdown]
# Identify pizza place from venue category and transform this category item to numerical value. This is predicted value I will use to build models. Venue crosssStreet also needs to be transform to numerical value. All the NA values will be transform to 0.

# %%
df_kcjo['Venue Category'].value_counts()
# Out:
# Clothing Store        90
# Pizza Place           77
# Sandwich Place        60
# Mexican Restaurant    57
# Coffee Shop           51
#                       ..
# Recruiting Agency      1
# Cheese Shop            1
# Taco Place             1
# Rock Climbing Spot     1
# Airport Terminal       1
# Name: Venue Category, Length: 166, dtype: int64

# %%
new=df_kcjo.copy()

new.loc[new['Venue Category'] == 'Pizza Place', 'Venue Category'] = 1
new.loc[new['Venue Category'] != 1, 'Venue Category'] = 0

new_jo=pd.to_numeric(new['Venue Category'], downcast='float')
new['Venue Category']=new_jo
new.dtypes
# Out:
# City                      object
# Postal Code               object
# Latitude                 float64
# Longitude                float64
# Venue                     object
# Venue Latitude           float64
# Venue Longitude          float64
# Venue Dis to entrance      int64
# Venue Category           float32
# Venue crosssSreet         object
# Employee No.              object
# Ann payroll               object
# dtype: object

# %%
new['Venue Category'].value_counts()
# Out:
# 0.0    1688
# 1.0      77
# Name: Venue Category, dtype: int64

# %%
df_kcjonson=new.copy()

df_kcjonson.loc[df_kcjonson['Venue crosssSreet'] == 'NA', 'Venue crosssSreet'] = 1
df_kcjonson.loc[df_kcjonson['Venue crosssSreet'] != 1, 'Venue crosssSreet'] = 0

new_jon=pd.to_numeric(df_kcjonson['Venue crosssSreet'], downcast='float')
df_kcjonson['Venue crosssSreet']=new_jon


new_jonkc=pd.to_numeric(df_kcjonson['Employee No.'], downcast='float')
df_kcjonson['Employee No.']=new_jonkc

new_jonkan=pd.to_numeric(df_kcjonson['Ann payroll'], downcast='float')
df_kcjonson['Ann payroll']=new_jonkan

new_jonkanp=pd.to_numeric(df_kcjonson['Postal Code'], downcast='float')
df_kcjonson['Postal Code']=new_jonkanp

df_kcjonson.dtypes
# Out:
# City                      object
# Postal Code              float32
# Latitude                 float64
# Longitude                float64
# Venue                     object
# Venue Latitude           float64
# Venue Longitude          float64
# Venue Dis to entrance      int64
# Venue Category           float32
# Venue crosssSreet        float32
# Employee No.             float32
# Ann payroll              float32
# dtype: object

# %%
df_kcjonson
# Out:
#                                                    City  Postal Code  \
# 0                          Shawnee/ Shawnee Mission/ Sm      66218.0
# 1                          Shawnee/ Shawnee Mission/ Sm      66218.0
# 2                          Shawnee/ Shawnee Mission/ Sm      66218.0
# 3                          Shawnee/ Shawnee Mission/ Sm      66218.0
# 4                          Shawnee/ Shawnee Mission/ Sm      66218.0
# ...                                                 ...          ...
# 1760   Leawood/ Overland/ Overland Park/ Shawnee Mis...      66211.0
# 1761   Leawood/ Overland/ Overland Park/ Shawnee Mis...      66211.0
# 1762   Leawood/ Overland/ Overland Park/ Shawnee Mis...      66211.0
# 1763   Leawood/ Overland/ Overland Park/ Shawnee Mis...      66211.0
# 1764   Leawood/ Overland/ Overland Park/ Shawnee Mis...      66211.0
#
#       Latitude  Longitude                                  Venue  \
# 0      39.0417   -94.7202                     West Flanders Park
# 1      39.0417   -94.7202     West Flanders Park & Walking Trail
# 2      39.0417   -94.7202                        Black Swan Lake
# 3      39.0417   -94.7202          Bierman's Christmas Tree Farm
# 4      39.0417   -94.7202          KC's Neighborhood Bar & Grill
# ...        ...        ...                                    ...
# 1760   38.9667   -94.6169  State Line Rd & Bannister Rd/ 95th St
# 1761   38.9667   -94.6169                           Ceramic Café
# 1762   38.9667   -94.6169                     Hallmark Creations
# 1763   38.9667   -94.6169                   Oz's MAQ Donut House
# 1764   38.9667   -94.6169                               Hallmark
#
#       Venue Latitude  Venue Longitude  Venue Dis to entrance  Venue Category  \
# 0          39.030392       -94.713196                   1396             0.0
# 1          39.029862       -94.713282                   1447             0.0
# 2          39.041802       -94.730938                    928             0.0
# 3          39.049750       -94.723537                    941             0.0
# 4          39.043677       -94.704676                   1360             0.0
# ...              ...              ...                    ...             ...
# 1760       38.956705       -94.608141                   1346             0.0
# 1761       38.957999       -94.629457                   1455             0.0
# 1762       38.958188       -94.629920                   1472             0.0
# 1763       38.956166       -94.627651                   1497             0.0
# 1764       38.957614       -94.629727                   1501             0.0
#
#       Venue crosssSreet  Employee No.  Ann payroll
# 0                   0.0        1280.0      64208.0
# 1                   0.0        1280.0      64208.0
# 2                   1.0        1280.0      64208.0
# 3                   1.0        1280.0      64208.0
# 4                   1.0        1280.0      64208.0
# ...                 ...           ...          ...
# 1760                1.0       30534.0    2447778.0
# 1761                1.0       30534.0    2447778.0
# 1762                1.0       30534.0    2447778.0
# 1763                1.0       30534.0    2447778.0
# 1764                0.0       30534.0    2447778.0
#
# [1765 rows x 12 columns]

# %%
 
map_jo = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, city in zip(df_kcjonson['Venue Latitude'], df_kcjonson['Venue Longitude'], df_kcjonson['City']):
    label = '{}'.format(city)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_jo)  
    
map_jo
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
